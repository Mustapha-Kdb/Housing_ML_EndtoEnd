# %%
import sys
from pathlib import Path

# Force notebook to recognize project root
import os
ROOT = Path(os.getcwd()).resolve().parents[0] # one level up from tests/
if str(ROOT) not in sys.path:
    sys.path.append(str(ROOT))

import pandas as pd
from src.inference_pipeline.inference import predict

# Load a few rows of already preprocessed data
sample_path = ROOT / "data/processed/cleaning_eval.csv"
df = pd.read_csv(sample_path).sample(5, random_state=42).reset_index(drop=True)

print("Input sample:")
display(df.head())

# Run inference
preds_df = predict(df)
print("✅ Predictions returned")
display(preds_df[["predicted_price"]].head())
# Out:
# 📂 Inference using project root: C:\Users\Mustapha\Desktop\ML-Project-Scratch
# Input sample:
#          date  median_sale_price  median_list_price  median_ppsf  \
# 0  2021-07-31           200000.0           199900.0   114.192813
# 1  2021-08-31           149900.0           222500.0   100.162866
# 2  2020-02-29           600000.0           662500.0   324.970278
# 3  2020-06-30           482500.0           499974.5   241.417762
# 4  2021-07-31           484500.0           489900.0   223.214286
#
#    median_list_ppsf  homes_sold  pending_sales  new_listings  inventory  \
# 0        122.133459       162.0          162.0         183.0      123.0
# 1        180.595039         5.0            7.0           8.0        5.0
# 2        341.947115        25.0           30.0          42.0       45.0
# 3        245.563021        38.0           47.0          46.0       41.0
# 4        234.624684        25.0           27.0          23.0       23.0
#
#    median_dom  ...  Median Home Value  Total Labor Force  \
# 0        49.0  ...           139100.0            19659.0
# 1        55.0  ...           234900.0              569.0
# 2        79.0  ...                0.0                0.0
# 3        35.0  ...           400200.0             4518.0
# 4        48.0  ...                0.0                0.0
#
#    Unemployed Population Total School Age Population  Total School Enrollment  \
# 0                 1823.0                     36555.0                  36555.0
# 1                   39.0                       978.0                    978.0
# 2                    0.0                         0.0                      0.0
# 3                  100.0                      8063.0                   8063.0
# 4                    0.0                         0.0                      0.0
#
#    Median Commute Time          price                         city_full  \
# 0              17194.0  192758.729590          Chicago-Naperville-Elgin
# 1                479.0  297813.925899  Minneapolis-St. Paul-Bloomington
# 2                  0.0  666820.438661       New York-Newark-Jersey City
# 3               4175.0  467000.867721           Boston-Cambridge-Newton
# 4                  0.0  533378.346341       New York-Newark-Jersey City
#
#        lat      lng
# 0  41.6675 -87.9597
# 1  45.1034 -93.2753
# 2  40.7222 -74.0225
# 3  42.5584 -71.1007
# 4  40.7222 -74.0225
#
# [5 rows x 41 columns]
# ⚠️ Skipping lat/lng merge: already present in DataFrame.
# ✅ Dropped 0 duplicate rows (excluding date/year).
# ✅ Removed 0 rows with median_list_price > 19M.
# ✅ Predictions returned
#    predicted_price
# 0    235338.734375
# 1    285179.968750
# 2    781375.750000
# 3    567558.250000
# 4    543511.500000
